# %%
! pip install SimpleITK
# Out:
# ...
#      |████████████████████████████████| 41.5 MB 7.4 MB/s eta 0:00:01    |▏                               | 153 kB 1.1 MB/s eta 0:00:38     |█████▊                          | 7.4 MB 4.0 MB/s eta 0:00:09     |██████                          | 7.9 MB 4.0 MB/s eta 0:00:09     |████████████▌                   | 16.3 MB 8.1 MB/s eta 0:00:04     |███████████████▋                | 20.3 MB 8.1 MB/s eta 0:00:03     |██████████████████▍             | 23.9 MB 8.1 MB/s eta 0:00:03     |████████████████████████████▌   | 37.0 MB 2.8 MB/s eta 0:00:02
# ...

# %%
import numpy as np
import pandas as pd
import skimage as im
import matplotlib.pyplot as plt
import pydicom
import SimpleITK as sitk

# %%
image_path = '../pigdicom/1.3.12.2.1107.5.2.31.30831.2013040319074561753595406.dcm'

image1 = pydicom.dcmread(image_path)

# %%
plt.imshow(image1.pixel_array, cmap=plt.cm.bone)

# %%
import os

# %%
stack_path = os.listdir('../pigdicom/')
